# %% [markdown]
# # **Basic Python**

# %% [markdown]
# ## 1.a
# Give a function F that takes a single argument n. This function should print a sequence of n strings as described in the examples below: <br>
# Ex: **n = 3**
#
# --A--<br>
# -BAB-<br>
# CBABC<br>
#
# **n = 4**
#
# ---A---<br>
# --BAB--<br>
# -CBABC-<br>
# DCBABCD

# %%
def F(n):
    for i in range (1 , n+1):
        sequences = ""
        for j in range(i):
            sequences += chr(65 + j)
        reversed_sequence = sequences[::-1]
        row = reversed_sequence + sequences[1:]

        padding = '-' * (n - i)
        print(padding + row + padding)

# Tests
F(10)
F(6)
# Out:
# ---------A---------
# --------BAB--------
# -------CBABC-------
# ------DCBABCD------
# -----EDCBABCDE-----
# ----FEDCBABCDEF----
# ---GFEDCBABCDEFG---
# --HGFEDCBABCDEFGH--
# -IHGFEDCBABCDEFGHI-
# JIHGFEDCBABCDEFGHIJ
# -----A-----
# ----BAB----
# ---CBABC---
# --DCBABCD--
# -EDCBABCDE-
# FEDCBABCDEF

# %% [markdown]
# ## 1.b
# Make a function F that takes only one argument, a dictionary(dict) d.
# The keys of d are integers and the values of d are a tuple of type (x (int), y (int)).
# You must print out the dict in the format "-key-, -x-, -y-" with each entry in a new line. Print it for each of the three sorted orders, by key values ascending, by x values descending, by y values ascending.

# %%
def F(d):
    print("Sorted by key (ascending):")
    for key in sorted(d.keys()):
        print(f"{key}, {d[key][0]}, {d[key][1]}")

    print("\nSorted by x values (descending):")
    for key, (x, y) in sorted(d.items(), key=lambda item: item[1][0], reverse=True):
        print(f"{key}, {x}, {y}")

    print("\nSorted by y values (ascending):")
    for key, (x, y) in sorted(d.items(), key=lambda item: item[1][1]):
        print(f"{key}, {x}, {y}")

    pass

# Tests
F({1 : (1, 2), 2 : (-1, 4), 5 : (-4, 3), 4 : (2, 3)})
F({-8 : (4, 2), 6 : (-3, 4), 7 : (2, 1), 5 : (9, -10)})
# Out:
# Sorted by key (ascending):
# 1, 1, 2
# 2, -1, 4
# 4, 2, 3
# 5, -4, 3
#
# Sorted by x values (descending):
# 4, 2, 3
# 1, 1, 2
# 2, -1, 4
# 5, -4, 3
#
# Sorted by y values (ascending):
# 1, 1, 2
# 5, -4, 3
# 4, 2, 3
# 2, -1, 4
# Sorted by key (ascending):
# -8, 4, 2
# 5, 9, -10
# 6, -3, 4
# 7, 2, 1
#
# Sorted by x values (descending):
# 5, 9, -10
# -8, 4, 2
# 7, 2, 1
# 6, -3, 4
#
# Sorted by y values (ascending):
# 5, 9, -10
# 7, 2, 1
# -8, 4, 2
# 6, -3, 4

# %% [markdown]
# ## 2 Working with Student Records
#
# Use the data in **student_records.csv** to complete the given tasks. Do not include any external libraries. Use a Python dictionary if required.
#
# ### Reference
# - [Python Dictionaries](https://www.w3schools.com/python/python_dictionaries.asp)

# %% [markdown]
# #### 2.a: open the student_records.csv file and print out the first 10 rows

# %%
import requests
#importing data from web
url = "https://raw.githubusercontent.com/mnp-club/CPP_Assignment/b20ef09c5389f4ca88f201b13bdcb9c8e488819c/student_records.csv"
response = requests.get(url)
file_path = "student_records.csv"
with open(file_path, "w") as file:
    file.write(response.text)

with open(file_path, 'r') as file:
     rows = file.readlines()

for row in rows[:10]:
    print(row.strip())
# Out:
# roll_number,department,credit,course_name,course_type,grade
#
# 588946,MA,3,EC250,hasmed_elective,AB
#
# 145372,EP,4,EP407,hasmed_elective,CC
#
# 834515,MA,8,EP885,hasmed_elective,BB
#
# 344265,CSE,6,CSE699,honours,AB

# %% [markdown]
# #### 2.b: Print out the total credits and calculte CPI of each student.
# CPI is the weighted average of core courses, and electives (weights being the letter grades converted to number AP,AA=10, AB=9, BB=8, BC=7, CC=6)

# %%
import requests
#importing data from web
url = "https://raw.githubusercontent.com/mnp-club/CPP_Assignment/b20ef09c5389f4ca88f201b13bdcb9c8e488819c/student_records.csv"
response = requests.get(url)

grade_to_points = {
    'AP': 10, 'AA': 10, 'AB': 9, 'BB': 8,
    'BC': 7, 'CC': 6
}

data = response.text.splitlines()

student_data = {}

for row in data[1:]:
    columns = row.strip().split(',')

    roll_no, departmnt, credits, course_name, course_type, grade  = columns[:6]

    if course_type == 'alc' or course_type == 'minor':
        continue
    credits = int(credits)
    grade_point = grade_to_points.get(grade.strip())
    if roll_no not in student_data:
        student_data[roll_no] = {'total_credits': 0, 'weighted_sum': 0}
    student_data[roll_no]['total_credits'] += credits
    student_data[roll_no]['weighted_sum'] += credits * grade_point

for roll_no, data in student_data.items():
    total_credits = data['total_credits']
    weighted_sum = data['weighted_sum']
    cpi = weighted_sum / total_credits

    print(f"Roll No: {roll_no}, Total Credits: {total_credits}, CPI: {cpi:.2f}")
# Out:
# Roll No: 588946, Total Credits: 135, CPI: 8.70
# Roll No: 145372, Total Credits: 116, CPI: 7.57
# Roll No: 834515, Total Credits: 178, CPI: 8.23
# Roll No: 344265, Total Credits: 107, CPI: 8.70
# Roll No: 781075, Total Credits: 200, CPI: 8.34
# Roll No: 836881, Total Credits: 144, CPI: 8.02
# Roll No: 310604, Total Credits: 146, CPI: 8.46
# Roll No: 773982, Total Credits: 196, CPI: 7.97
# Roll No: 500658, Total Credits: 154, CPI: 8.11
# Roll No: 810863, Total Credits: 121, CPI: 8.14
# Roll No: 364146, Total Credits: 134, CPI: 8.60
# Roll No: 871746, Total Credits: 139, CPI: 7.90
# Roll No: 718510, Total Credits: 142, CPI: 8.54
# Roll No: 836431, Total Credits: 120, CPI: 8.07
# Roll No: 379479, Total Credits: 207, CPI: 7.97
# Roll No: 582912, Total Credits: 163, CPI: 8.79
# Roll No: 788020, Total Credits: 114, CPI: 7.99
# Roll No: 613401, Total Credits: 169, CPI: 8.49
# Roll No: 680096, Total Credits: 116, CPI: 8.26
# Roll No: 199713, Total Credits: 126, CPI: 8.29
# ...

# %% [markdown]
# #### 2.c: Print out the roll numbers of all students who meet the graduation requirements
# Atleast 20 credist of core course, 15 credits of department elective, 10 credits of flexible elective and 5 credits of hasmed electives

# %%
import requests
#importing data from web
url = "https://raw.githubusercontent.com/mnp-club/CPP_Assignment/b20ef09c5389f4ca88f201b13bdcb9c8e488819c/student_records.csv"
response = requests.get(url)
data = response.text.splitlines()

student_data = {}

for row in data[1:]:
    columns = row.strip().split(',')
    roll_no, departmnt, credits, course_name, course_type, grade = columns[:6]
    credits = int(credits)

    if roll_no not in student_data:
        student_data[roll_no] = {
            'core': 0,
            'department_elective': 0,
            'flexible_elective': 0,
            'hasmed_elective': 0
        }


    if course_type == 'core':
        student_data[roll_no]['core'] += credits
    elif course_type == 'department_elective':
        student_data[roll_no]['department_elective'] += credits
    elif course_type == 'flexible_elective':
        student_data[roll_no]['flexible_elective'] += credits
    elif course_type == 'hasmed_elective':
        student_data[roll_no]['hasmed_elective'] += credits


print("Students meeting graduation requirements:")
for roll_no in student_data:

    if (student_data[roll_no]['core'] >= 20 and
        student_data[roll_no]['department_elective'] >= 15 and
        student_data[roll_no]['flexible_elective'] >= 10 and
        student_data[roll_no]['hasmed_elective'] >= 5):
        print(roll_no)
# Out:
# Students meeting graduation requirements:
# 588946
# 834515
# 781075
# 180828
# 981238
# 836881
# 310604
# 773982
# 500658
# 810863
# 124663
# 871746
# 986057
# 379479
# 144528
# 485484
# 845623
# 150503
# 214270
# 517837
# 482623
# 721490
# 955757
# 143856
# 571782
# 973158
# 703403
# 960395
# 521087
# 461971
# 879634
# 716985
# 265922
# 283796
# 203200
# 327122
# 534763
# 391848
# 971123
# 207443
# 488661
# 782129
# 928288
# 581858
# 282482
# 572815
# 608952
# 628849
# 630568
# 388969
# 159438
# 970791
# 143142
# 998293
# 681499
# 888886
# 608522
# 362471
# 692318
# 626000
# 581065
# 787967
# 381227
# 750259
# 881983
# 294697

# %% [markdown]
# #### 2.d: Print out the roll numbers of all students who completed a minor
# Atleast 10 credits with minor tag in a specific department

# %%
student_data = {}


for row in data[1:]:
    columns = row.strip().split(',')
    roll_no, department, credits, course_name, course_type, grade = columns[:6]
    credits = int(credits)

    if 'minor' in course_type:
      if roll_no not in student_data:
        student_data[roll_no] = {}
        if department not in student_data[roll_no]:
            student_data[roll_no][department] = 0
      student_data[roll_no][department] += credits

print("Students completing a minor:")
for roll_no in student_data:
  for department in student_data[roll_no]:
    if student_data[roll_no][department] >= 10:
        print(roll_no)
# Out:
# Students completing a minor:
# 358405
# 180828
# 981238
# 847809
# 270007
# 781075
# 986057
# 124663
# 364146
# 517837
# 721490
# 150503
# 571782
# 716985
# 194063
# 265922
# 482623
# 329535
# 207443
# 810863
# 973158
# 143142
# 970791
# 907454
# 888886
# 608522
# 608952
# 143856
# 773982
# 960395
# 283796
# 461584
# 879634
# 597353
# 845623
# 465496
# 718510
# 534763
# 680096
# 836881
# 787967
# 344265
# 581858
# 391848
# 485484
# 775967
# 138296
# 381526
# 681499
# 816041
# 971123
# 199713
# 630568
# 379479
# 362471
# 703403
# 388969
# 836431
# 582912
# 381227
# 478606
# 159438
# 733782
# 782129
# 144528
# 851029
# 881983
# 458200
# 998293
# 628849
# 995208
# 613401
# 301135
# 500658
# 488661
# 788020
# 626000
# 955757
# 841365
# 750259
# 572815
# 521087
# 214270
# 461971
# 692318
# 145372
# 588946
# 834515
# 208100
# 871746
# 327122
# 581065
# 203200
# 294697
# 993835
# 282482

# %% [markdown]
# #### 2.e: Print out the roll numbers of all students who completed a honours
# Atleast 10 credits with honours tag and 20 core credits

# %%
student_data = {}

for row in data[1:]:
    columns = row.strip().split(',')

    roll_no, department, credits, course_name, course_type, grade = columns[:6]
    credits = int(credits)

    if roll_no not in student_data:
        student_data[roll_no] = {}

    if course_type not in student_data[roll_no]:
        student_data[roll_no][course_type] = 0

    if 'honours' in course_type:
        student_data[roll_no][course_type] += credits
    elif 'core' in course_type:
        student_data[roll_no][course_type] += credits

print("Students completing honours:")
for roll_no in student_data:
    if (student_data[roll_no].get('honours', 0) >= 10 and
        student_data[roll_no].get('core', 0) >= 20):
        print(roll_no)
# Out:
# Students completing honours:
# 588946
# 145372
# 834515
# 781075
# 836881
# 310604
# 773982
# 500658
# 810863
# 124663
# 364146
# 871746
# 986057
# 718510
# 379479
# 582912
# 788020
# 613401
# 144528
# 485484
# 199713
# 845623
# 150503
# 214270
# 517837
# 482623
# 721490
# 955757
# 589528
# 143856
# 571782
# 973158
# 703403
# 960395
# 521087
# 461971
# 879634
# 716985
# 265922
# 283796
# 203200
# 327122
# 534763
# 391848
# 971123
# 207443
# 488661
# 782129
# 928288
# 581858
# 282482
# 572815
# 608952
# 628849
# 630568
# 388969
# 159438
# 870642
# 970791
# 143142
# 998293
# 681499
# 888886
# 608522
# 362471
# 465496
# 208100
# 692318
# 626000
# 458200
# 581065
# 787967
# 750259
# 881983
# 294697

# %% [markdown]
# # **SciPy**

# %% [markdown]
# ## Part A
# Minimize the function $f(x, y) = 2(x - y - 3)^2 + 4(x + 2y + 1)^4$.<br>
# With the constraints : $ x - y \ge -3, (x + 2)^2 + (y + 1)^2 \le 5$ <br>
# Using scipy.optimize.minimize with constraints. (Hint: Look at the examples in the official documentation)

# %%
import numpy as np
from scipy.optimize import minimize

def objFun(var):
    x, y = var
    return 2 * (x-y-3)**2 + 4 * (x + 2*y + 1)**4

def constraints1(var):
    x, y = var
    return y-x+3

def constraints2(var):
    x,y = var
    return 5 - ((x+2)**2 + (y+1)**2)

initial_guess = [0,0]
constraints = [
    {'type': 'ineq', 'fun': constraints1},  
    {'type': 'ineq', 'fun': constraints2}   
]

output = minimize(objFun , initial_guess, constraints= constraints, method= 'SLSQP')

if output.success:
    print("Optimal solution found:")
    print(f"x = {output.x[0]:.4f}, y = {output.x[1]:.4f}")
    print(f"Minimum value of the function: {output.fun:.4f}")
else:
    print("Optimization failed:", output.message)
# Out:
# Optimal solution found:
# x = 0.2349, y = -0.9285
# Minimum value of the function: 7.3450

# %% [markdown]
# # Part B
# Evaluate the line integral of the function $f(x, y) = x^2 + y^4$ along the circle $ x^2 + y^2 = 3 $ anticlockwise (scalar integral, not vector). You must use scipy for integration but you may use parameterization

# %%
import numpy as np
from scipy.integrate import quad

def integrand(t):
    x = np.sqrt(3)*np.cos(t)
    y = np.sqrt(3)*np.sin(t)

    f_xy = x**2 + y**4
    
    arc_len = np.sqrt(3)
    return f_xy * arc_len

result , error = quad(integrand, 0, 2*np.pi)
print(f"The value of the line integral (quad) is approximately: {result:.4f}")
# Out:
# The value of the line integral (quad) is approximately: 53.0536

# %% [markdown]
# # **Numpy**

# %% [markdown]
# ### Read Lisan_Al_Gaib.pdf for problem description and complete the following functions

# %%
import time # to time the execution
import numpy as np
import matplotlib.pyplot as plt

# %%
def load_data(data_path):
    data = np.loadtxt(data_path, delimiter=',')  
    return data

# %%
def initialise_centers(data, K, init_centers=None):
    if init_centers is None:
        centers = data[np.random.choice(data.shape[0], K, replace=False)]
    else:
        centers = np.array(init_centers)
    return centers

# %%
def initialise_labels(data):
    N = data.shape[0]
    labels = np.ones(N, dtype=int)
    return labels

# %%
def calculate_distances(data, centers):
    distances = np.linalg.norm(data[:, np.newaxis, :] - centers, axis=2)
    return distances

# %%
def update_labels(distances):
    labels = np.argmin(distances, axis=1)
    return labels

# %%
def update_centers(data, labels, K):

    cluster_sums = np.zeros((K, data.shape[1]))
    cluster_counts = np.zeros(K)
    
    np.add.at(cluster_sums, labels, data)  
    np.add.at(cluster_counts, labels, 1)  
   
    new_centers = cluster_sums / cluster_counts[:, None]
    return new_centers

# %%
def check_termination(labels1, labels2):
    return np.array_equal(labels1, labels2)

# %%
### DON'T CHANGE ANYTHING IN THE FOLLOWING FUNCTION
def kmeans(data_path:str, K:int, init_centers):
    '''
    Input :
        data (type str): path to the file containing the data
        K (type int): number of clusters
        init_centers (type numpy.ndarray): initial centers. shape = (K, 2) or None
    Output :
        centers (type numpy.ndarray): final centers. shape = (K, 2)
        labels (type numpy.ndarray): label of each data point. shape = (N,)
        time (type float): time taken by the algorithm to converge in seconds
    N is the number of data points each of shape (2,)
    '''
    data = load_data(data_path)    
    centers = initialise_centers(data, K, init_centers)
    labels = initialise_labels(data)

    start_time = time.time() # Time stamp 

    while True:
        distances = calculate_distances(data, centers)
        labels_new = update_labels(distances)
        centers = update_centers(data, labels_new, K)
        if check_termination(labels, labels_new): break
        else: labels = labels_new
 
    end_time = time.time() # Time stamp after the algorithm ends
    return centers, labels, end_time - start_time

# %%
def visualise(data_path, labels, centers):
    data = load_data(data_path)

    # Scatter plot of the data points
    plt.scatter(data[:, 0], data[:, 1], c=labels, s=50, cmap='viridis')
    
    plt.scatter(centers[:, 0], centers[:, 1], c='black', s=200, alpha=0.5, marker='X')

    plt.title('K-means clustering')

    plt.xlabel('Longitude')

    plt.ylabel('Latitude')

    plt.savefig('kmeans.png')

    ## DO NOT CHANGE THE FOLLOWING LINE
    return plt

# %%
### After you have completed the above functions, run the following code to generate the plot
data_path = 'spice_locations.txt'
K, init_centers = 2, None
centers, labels, time_taken = kmeans(data_path, K, init_centers)
print('Time taken for the algorithm to converge:', time_taken)
visualise(data_path, labels, centers)
